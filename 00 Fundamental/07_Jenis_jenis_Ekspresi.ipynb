# %% [markdown]
# <a href="https://colab.research.google.com/github/NugiePhysics/Fundamental-Python/blob/main/07_Jenis_jenis_Ekspresi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ekspresi Menurut Arity dari Operator

# %%
a = True
a = not a
print(a)

b = 6
b -= 1
print(b)

c = 6
c += 1
print(c)

d = 10
print(-d)
# Out:
# False
# 5
# 7
# -10

# %% [markdown]
# # Ekspresi Menurut Tipe Data yang Dihasilkan

# %%
print(2+2)
print(3<10)
print(True or False)
# Out:
# 4
# True
# True
