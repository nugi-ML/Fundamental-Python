# %% [markdown]
# <a href="https://colab.research.google.com/github/NugiePhysics/Fundamental-Python/blob/main/03_Data_Typing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Nugi"
age = 17
salary = 5000000.0

print(type(name))
print(type(age))
print(type(salary))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
