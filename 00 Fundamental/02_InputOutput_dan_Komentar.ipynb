# %% [markdown]
# <a href="https://colab.research.google.com/github/NugiePhysics/Fundamental-Python/blob/main/02_InputOutput_dan_Komentar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ini adalah komentar, tidak akan di eksekusi
name = input('Masukan nama Anda: ') # Input
print(name)

"""
Ini adalah Block comment,
Teks ini akan diabaikan oleh Python.
"""
# Out:
# Masukan nama Anda: Nugi
# Nugi
# '\nIni adalah Block comment,\nTeks ini akan diabaikan oleh Python.\n'
